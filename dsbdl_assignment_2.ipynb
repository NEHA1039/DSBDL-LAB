# %% [markdown]
# <a href="https://colab.research.google.com/github/NEHA1039/DSBDL-LAB/blob/main/dsbdl_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Demo Marks.xlsx")

# %%
df
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131        NaN        29.0
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# ...

# %%
df.isnull()
# Out:
#     Roll no  Name of Student  Previous Year SPPU Total Marks out of  1400  \
# 0     False            False                                        False
# 1     False            False                                        False
# 2     False            False                                        False
# 3     False            False                                        False
# 4     False            False                                        False
# ..      ...              ...                                          ...
# 69    False            False                                        False
# 70    False            False                                        False
# 71    False            False                                        False
# 72    False            False                                        False
# 73    False            False                                        False
#
#         %  UT 1 Marks    %.1  50% maks of Previous Year SPPU Result  \
# ...

# %%
df.notnull()
# Out:
#     Roll no  Name of Student  Previous Year SPPU Total Marks out of  1400  \
# 0      True             True                                         True
# 1      True             True                                         True
# 2      True             True                                         True
# 3      True             True                                         True
# 4      True             True                                         True
# ..      ...              ...                                          ...
# 69     True             True                                         True
# 70     True             True                                         True
# 71     True             True                                         True
# 72     True             True                                         True
# 73     True             True                                         True
#
#         %  UT 1 Marks    %.1  50% maks of Previous Year SPPU Result  \
# ...

# %%
df.dropna()
# Out:
#     Roll no            Name of Student  \
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# 5         6    THETE SANJIVANI SANTOSH
# ..      ...                        ...
# 67       68        KEDAR PAVAN PRALHAD
# 68       69      PARMAR DEEPAK PRAKASH
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# 5                                          1129  80.642857        29.0
# ...

# %%
df.fillna(0)
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131   0.000000        29.0
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# ...

# %%
df.replace(to_replace=np.nan,value=-99)
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131 -99.000000        29.0
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# ...

# %%
df['UT 1 Marks']=df['UT 1 Marks'].fillna(df['UT 1 Marks'].mean())

# %%
df['UT 1 Marks']=df['UT 1 Marks'].fillna(df['UT 1 Marks'].median())

# %%
df['UT 1 Marks']=df['UT 1 Marks'].fillna(df['UT 1 Marks'].std())

# %%
df
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131        NaN   29.000000
# 1                                          1107  79.071429   29.000000
# 2                                           995  71.071429   27.000000
# 3                                          1077  76.928571   28.000000
# 4                                          1064  76.000000   28.000000
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Demo Marks.xlsx")

# %%
col = ['%', 'UT 1 Marks' , '%.1']
df.boxplot(col)
# Out:
# <Axes: >

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("/content/Demo Marks.xlsx")

# %%
import matplotlib.pyplot as plt
df['%'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['log_math'] = np.log10(df['UT 1 Marks'])

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
