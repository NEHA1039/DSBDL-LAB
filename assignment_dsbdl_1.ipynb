# %% [markdown]
# <a href="https://colab.research.google.com/github/NEHA1039/DSBDL-LAB/blob/main/assignment_dsbdl_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(5)
# Out:
#    Id  SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0   1          5.1         3.5          1.4         0.2  Setosa
# 1   2          4.9         3.0          1.4         0.2  Setosa
# 2   3          4.7         3.2          1.3         0.2  Setosa
# 3   4          4.6         3.1          1.5         0.2  Setosa
# 4   5          5.0         3.6          1.4         0.2  Setosa

# %%
df.tail(5)
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 145  146          6.7         3.0          5.2         2.3  Virginica
# 146  147          6.3         2.5          5.0         1.9  Virginica
# 147  148          6.5         3.0          5.2         2.0  Virginica
# 148  149          6.2         3.4          5.4         2.3  Virginica
# 149  150          5.9         3.0          5.1         1.8  Virginica

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id               int64
# SepalLength    float64
# SepalWidth     float64
# PetalLength    float64
# PetalWidth     float64
# Species         object
# dtype: object

# %%
df.iloc[5]
# Out:
# Id                  6
# SepalLength       5.4
# SepalWidth        3.9
# PetalLength       1.7
# PetalWidth        0.4
# Species        Setosa
# Name: 5, dtype: object

# %%
df.isnull()
# Out:
#         Id  SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0    False        False       False        False       False    False
# 1    False        False       False        False       False    False
# 2    False        False       False        False       False    False
# 3    False        False       False        False       False    False
# 4    False        False       False        False       False    False
# ..     ...          ...         ...          ...         ...      ...
# 145  False        False       False        False       False    False
# 146  False        False       False        False       False    False
# 147  False        False       False        False       False    False
# 148  False        False       False        False       False    False
# 149  False        False       False        False       False    False
#
# [150 rows x 6 columns]

# %%
df.isna()
# Out:
#         Id  SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0    False        False       False        False       False    False
# 1    False        False       False        False       False    False
# 2    False        False       False        False       False    False
# 3    False        False       False        False       False    False
# 4    False        False       False        False       False    False
# ..     ...          ...         ...          ...         ...      ...
# 145  False        False       False        False       False    False
# 146  False        False       False        False       False    False
# 147  False        False       False        False       False    False
# 148  False        False       False        False       False    False
# 149  False        False       False        False       False    False
#
# [150 rows x 6 columns]

# %%
from sklearn import preprocessing

# %%
x=df[['PetalWidth']].values.astype(float)
min_max_scaler=preprocessing.MinMaxScaler()
x_scaler=min_max_scaler.fit_transform(x)
df_normalized=pd.DataFrame(x_scaler)

# %%
df_normalized
# Out:
#             0
# 0    0.041667
# 1    0.041667
# 2    0.041667
# 3    0.041667
# 4    0.041667
# ..        ...
# 145  0.916667
# 146  0.750000
# 147  0.791667
# 148  0.916667
# 149  0.708333
#
# [150 rows x 1 columns]

# %%
from sklearn import preprocessing

# %%
df['Species'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
df['Species']=label_encoder.fit_transform(df['Species'])
df['Species'].unique()
# Out:
# array([0, 1, 2])
