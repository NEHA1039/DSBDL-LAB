# %% [markdown]
# <a href="https://colab.research.google.com/github/NEHA1039/DSBDL-LAB/blob/main/dsbda_assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import load_dataset

data = pd.read_csv("/content/titanic.csv")

tips = load_dataset("tips")

# %%
sns.countplot(data['Survived'])
plt.show()

# %%
data['Sex'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
plt.hist(data['Age'], bins=5)
plt.show()

# %%
sns.distplot(data['Age'])
plt.show()
# Out:
# /tmp/ipykernel_3967/585942754.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])

# %%
sns.scatterplot(x=tips["total_bill"], y=tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips["total_bill"], y=tips["tip"], hue=tips["sex"])
plt.show()

# %%
sns.scatterplot(x=tips["total_bill"], y=tips["tip"], hue=tips["sex"],
style=tips['smoker'])
plt.show()

# %%
sns.barplot(x=data['Pclass'], y=data['Age'])
plt.show()

# %%
sns.barplot(x=data['Pclass'], y=data['Fare'], hue = data["Sex"])
plt.show()

# %%
sns.boxplot(x=data['Sex'], y=data["Age"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=data['Sex'], y=data["Age"], hue=data["Survived"])
plt.show()

# %%
sns.distplot(data[data['Survived'] == 0]['Age'], hist=False, color="blue")
sns.distplot(data[data['Survived'] == 1]['Age'], hist=False, color="orange")
plt.show()
# Out:
# /tmp/ipykernel_3967/2068831470.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Survived'] == 0]['Age'], hist=False, color="blue")
# /tmp/ipykernel_3967/2068831470.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[data['Survived'] == 1]['Age'], hist=False, color="orange")

# %%
pd.crosstab(data['Pclass'], data['Survived'])
sns.heatmap(pd.crosstab(data['Pclass'], data['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(data['Parch'], data['Survived']))
plt.show()
