# %% [markdown]
# <a href="https://colab.research.google.com/github/NEHA1039/DSBDL-LAB/blob/main/dsbda_assignment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/iris.csv')

# %%
data.head(3)
# Out:
#    Id  SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0   1          5.1         3.5          1.4         0.2  Setosa
# 1   2          4.9         3.0          1.4         0.2  Setosa
# 2   3          4.7         3.2          1.3         0.2  Setosa

# %%
data.tail(3)
# Out:
#       Id  SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 147  148          6.5         3.0          5.2         2.0  Virginica
# 148  149          6.2         3.4          5.4         2.3  Virginica
# 149  150          5.9         3.0          5.1         1.8  Virginica

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           150 non-null    int64
#  1   SepalLength  148 non-null    float64
#  2   SepalWidth   150 non-null    float64
#  3   PetalLength  150 non-null    float64
#  4   PetalWidth   148 non-null    float64
#  5   Species      150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLength  SepalWidth  PetalLength  PetalWidth
# count  150.000000   148.000000  150.000000   150.000000  148.000000
# mean    75.500000     5.856757    3.054000     3.758667    1.197973
# std     43.445368     0.825459    0.433594     1.764420    0.760278
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     38.250000     5.100000    2.800000     1.600000    0.300000
# 50%     75.500000     5.800000    3.000000     4.350000    1.300000
# 75%    112.750000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
data.columns
# Out:
# Index(['Id', 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
data["Species"].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
sum_data = data["SepalLength"].sum()
mean_data = data["SepalLength"].mean()
median_data = data["SepalLength"].median()
print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 866.8
# Mean: 5.856756756756757
# Median: 5.8

# %%
newcols={
"Id":"id",
"SepalLengthCm":"sepallength",
"SepalWidthCm":"sepalwidth"}

data.rename(columns=newcols,inplace=True)

print(data.head())
# Out:
#    id  SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0   1          5.1         3.5          1.4         0.2  Setosa
# 1   2          4.9         3.0          1.4         0.2  Setosa
# 2   3          4.7         3.2          1.3         0.2  Setosa
# 3   4          4.6         3.1          1.5         0.2  Setosa
# 4   5          5.0         3.6          1.4         0.2  Setosa

# %%
import numpy as np
numeric_data_head = data.head(10).select_dtypes(include=np.number)
numeric_data_head.style.highlight_max(color='lightgreen', axis=0)
numeric_data_head.style.highlight_max(color='lightgreen', axis=1)
numeric_data_head.style.highlight_max(color='lightgreen', axis=None)
# Out:
# <style type="text/css">
# #T_a02f1_row9_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a02f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a02f1_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_a02f1_level0_col1" class="col_heading level0 col1" >SepalLength</th>
#       <th id="T_a02f1_level0_col2" class="col_heading level0 col2" >SepalWidth</th>
#       <th id="T_a02f1_level0_col3" class="col_heading level0 col3" >PetalLength</th>
#       <th id="T_a02f1_level0_col4" class="col_heading level0 col4" >PetalWidth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a02f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a02f1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a02f1_row0_col1" class="data row0 col1" >5.100000</td>
#       <td id="T_a02f1_row0_col2" class="data row0 col2" >3.500000</td>
# ...

# %%
import seaborn as sns

iris = sns.load_dataset("iris")
sns.heatmap(iris.select_dtypes(include=['number']).corr(), cmap = "YlGnBu", linecolor = 'white', linewidths = 1)
# Out:
# <Axes: >

# %%
sns.heatmap(iris.select_dtypes(include=['number']).corr(), cmap = "YlGnBu", linecolor = 'white', linewidths = 1, annot = True )
# Out:
# <Axes: >

# %%
data.select_dtypes(include=['number']).corr(method='pearson')
# Out:
#                    id  SepalLength  SepalWidth  PetalLength  PetalWidth
# id           1.000000     0.711209   -0.397729     0.882747    0.899398
# SepalLength  0.711209     1.000000   -0.110715     0.869032    0.812222
# SepalWidth  -0.397729    -0.110715    1.000000    -0.420516   -0.349005
# PetalLength  0.882747     0.869032   -0.420516     1.000000    0.962101
# PetalWidth   0.899398     0.812222   -0.349005     0.962101    1.000000

# %%
g = sns.pairplot(data,hue="Species")
